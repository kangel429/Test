# %%
from PIL import Image
from pylab import *
import matplotlib

# %%
im = Image.open('1.jpg')

# %%
imshow(im)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-afbdf33aed57> in <module>
# ----> 1 im.shape
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'
