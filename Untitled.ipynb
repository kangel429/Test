# %%
from PIL import Image
from pylab import *
import matplotlib
import skimage

# %%
im = Image.open('1.jpg')

# %%
imshow(im)

# %%
x = [100,100,400,400]

# %%
y = [200,500,200,500]

# %%
plot(x,y,'go-')

# %%
plot(x[:3],y[:3])

# %%
plot(x,y,'ks:')

# %%
show()

# %%
imm = array(Image.open('1.jpg').convert('L'))

# %%
figure()

# %%
gray()

# %%
contour(imm, origin='image')

# %%
axis('equal')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
hist(imm.flatten(),128)
# Out:
# (array([3.0000e+00, 4.4000e+01, 1.4600e+02, 2.0600e+02, 1.5800e+02,
#         1.4200e+02, 1.9800e+02, 2.3600e+02, 2.4600e+02, 1.4900e+02,
#         3.8500e+02, 4.1200e+02, 4.7800e+02, 5.0200e+02, 5.5900e+02,
#         5.8400e+02, 6.9000e+02, 8.3500e+02, 1.0200e+03, 5.3400e+02,
#         1.4300e+03, 1.6660e+03, 1.9650e+03, 2.6050e+03, 3.2720e+03,
#         3.5540e+03, 3.4170e+03, 3.7690e+03, 3.6660e+03, 1.9800e+03,
#         4.0110e+03, 4.0240e+03, 3.9390e+03, 4.0400e+03, 3.9230e+03,
#         3.9990e+03, 4.1080e+03, 4.0470e+03, 4.4620e+03, 2.3400e+03,
#         4.8370e+03, 4.8860e+03, 4.8530e+03, 4.7010e+03, 4.7770e+03,
#         4.6620e+03, 4.5690e+03, 4.8370e+03, 5.2170e+03, 2.7390e+03,
#         5.7380e+03, 6.1090e+03, 6.7280e+03, 6.8760e+03, 7.2810e+03,
#         7.4080e+03, 7.7830e+03, 7.8980e+03, 7.6480e+03, 3.6990e+03,
#         7.5510e+03, 7.2710e+03, 7.0680e+03, 7.0230e+03, 6.8190e+03,
#         6.3130e+03, 5.9320e+03, 5.8290e+03, 2.8040e+03, 5.8970e+03,
# ...

# %%
show()

# %%
imq = array(Image.open('1.jpg'))

# %%
imshow(imq)

# %%
x = ginput(3)
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
print ('you clicked:',x)
# Out:
# you clicked: []

# %%
show()

# %%
print (imq.shape, imq.dtype)
# Out:
# (734, 1100, 3) uint8

# %%
imw = array(Image.open('1.jpg').convert('L'),'f')

# %%
print (imw.shape, imw.dtype)
# Out:
# (734, 1100) float32

# %%
im[250,400]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-bcc2aea38353> in <module>
# ----> 1 im[250,400]
#
# TypeError: 'JpegImageFile' object is not subscriptable
